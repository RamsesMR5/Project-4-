# %%
import pandas as pd
import numpy as np
import sqlalchemy as alch
from getpass import getpass
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
da_df = pd.read_csv("data/ds_salaries.csv")
da_df
# Out:
#       work_year experience_level employment_type                 job_title
# 0          2023               SE              FT  Principal Data Scientist  \
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio
# 0       80000             EUR          85847                 ES           100  \
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L
#
# [3755 rows x 11 columns]

# %%
da_df.sample(10
        )
# Out:
#       work_year experience_level employment_type       job_title  salary
# 1852       2022               SE              FT   Data Engineer   63000  \
# 1033       2023               SE              FT    Data Manager   44737
# 2908       2022               SE              FT    Data Analyst  115000
# 863        2023               SE              FT    Data Analyst  110000
# 2152       2022               SE              FT     ML Engineer  243000
# 878        2023               SE              FT   Data Engineer  252000
# 1721       2023               SE              FT    NLP Engineer  135000
# 1813       2023               MI              FT    Data Analyst  100000
# 2733       2022               SE              FT  Data Scientist  148000
# 2236       2022               MI              FT   Data Engineer   90000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio
# 1852             USD          63000                 US           100  \
# 1033             GBP          54365                 GB             0
# 2908             USD         115000                 US             0
# 863              USD         110000                 US             0
# 2152             USD         243000                 US           100
# 878              USD         252000                 US             0
# 1721             USD         135000                 US             0
# 1813             USD         100000                 US             0
# 2733             USD         148000                 US           100
# 2236             USD          90000                 US           100
#
#      company_location company_size
# 1852               US            M
# 1033               GB            M
# 2908               US            L
# 863                US            M
# 2152               US            M
# 878                US            M
# 1721               US            M
# 1813               US            M
# 2733               US            M
# 2236               US            M

# %%
da_df = da_df[da_df["salary_currency"].str.contains("INR")==False]

# %%
da_df = da_df[da_df["employment_type"].str.contains("CT")==False]

# %%
da_df
# Out:
#       work_year experience_level employment_type                 job_title
# 0          2023               SE              FT  Principal Data Scientist  \
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# 5          2023               SE              FT         Applied Scientist
# 6          2023               SE              FT         Applied Scientist
# ...         ...              ...             ...                       ...
# 3748       2021               MI              FT             Data Engineer
# 3749       2021               SE              FT           Data Specialist
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio
# 0      80000             EUR          85847                 ES           100  \
# 3     175000             USD         175000                 CA           100
# 4     120000             USD         120000                 CA           100
# 5     222200             USD         222200                 US             0
# 6     136000             USD         136000                 US             0
# ...      ...             ...            ...                ...           ...
# 3748   24000             EUR          28369                 MT            50
# 3749  165000             USD         165000                 US           100
# 3750  412000             USD         412000                 US           100
# 3751  151000             USD         151000                 US           100
# 3752  105000             USD         105000                 US           100
#
#      company_location company_size
# 0                  ES            L
# 3                  CA            M
# 4                  CA            M
# 5                  US            L
# 6                  US            L
# ...               ...          ...
# 3748               MT            L
# 3749               US            L
# 3750               US            L
# 3751               US            L
# 3752               US            S
#
# [3685 rows x 11 columns]

# %%
def connection_to_sql (dbName):
    password=os.getenv("password") 
    connectionData = f"mysql+pymysql://root:{password}@localhost/{dbName}"
    engine = alch.create_engine(connectionData)
    return engine

# %%
engine = connection_to_sql ("project-4")

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/project-4)

# %%
table_name = "da_df"
da_df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
# Out:
# 3685

# %%
def execute_sql_query(query):
    engine = connection_to_sql ("project-4")
    results = pd.read_sql_query(query, engine)
    return results

# %%
query = "SELECT salary_in_usd, job_title, work_year FROM da_df WHERE job_title in ('data engineer', 'data scientist', 'data analyst') order by salary_in_usd desc;"

results = execute_sql_query(query)

print(results)
# Out:
#       salary_in_usd       job_title  work_year
# 0            430967    Data Analyst       2022
# 1            412000  Data Scientist       2020
# 2            385000    Data Analyst       2023
# 3            370000  Data Scientist       2023
# 4            350000  Data Scientist       2022
# ...             ...             ...        ...
# 2456          10354    Data Analyst       2021
# 2457          10000  Data Scientist       2022
# 2458          10000    Data Analyst       2020
# 2459           8000    Data Analyst       2020
# 2460           7799    Data Analyst       2022
#
# [2461 rows x 3 columns]

# %%
query = "SELECT AVG(salary_in_usd) AS average_salary, job_title, work_year FROM da_df WHERE job_title IN ('data engineer', 'data scientist', 'data analyst') GROUP BY job_title, work_year ORDER BY average_salary DESC;"

results = execute_sql_query(query)

print(results)
# Out:
#     average_salary       job_title  work_year
# 0      158382.7350  Data Scientist       2023
# 1      151917.6205   Data Engineer       2023
# 2      139803.4004   Data Engineer       2022
# 3      138112.4160  Data Scientist       2022
# 4      114418.6895    Data Analyst       2023
# 5      108356.0772    Data Analyst       2022
# 6       97703.6667   Data Engineer       2021
# 7       88245.0000  Data Scientist       2020
# 8       85301.3846   Data Engineer       2020
# 9       82415.1892  Data Scientist       2021
# 10      77931.0000    Data Analyst       2021
# 11      47938.2857    Data Analyst       2020

# %%
query = "SELECT COUNT(job_title) as total_jobs, work_year, experience_level FROM da_df WHERE job_title in ('Data Engineer', 'Data Scientist', 'Data Analyst') GROUP BY work_year, experience_level ORDER BY total_jobs;"

results = execute_sql_query(query)

print(results)
# Out:
#     total_jobs  work_year experience_level
# 0            1       2020               EX
# 1            7       2020               SE
# 2           12       2020               EN
# 3           18       2022               EX
# 4           19       2021               EN
# 5           20       2020               MI
# 6           24       2021               SE
# 7           46       2023               EX
# 8           50       2021               MI
# 9           70       2022               EN
# 10          73       2023               EN
# 11         205       2023               MI
# 12         244       2022               MI
# 13         826       2022               SE
# 14         846       2023               SE

# %%
query = "SELECT COUNT(job_title) AS total_jobs, work_year, remote_ratio, job_title FROM da_df WHERE job_title in ('Data Engineer', 'Data Scientist', 'Data Analyst') GROUP BY work_year, remote_ratio, job_title ORDER BY remote_ratio ASC;"

results = execute_sql_query(query)

print(results)
# Out:
#     total_jobs  work_year  remote_ratio       job_title
# 0            2       2021             0    Data Analyst
# 1          229       2023             0  Data Scientist
# 2            1       2020             0   Data Engineer
# 3          333       2023             0   Data Engineer
# 4          185       2023             0    Data Analyst
# 5            4       2021             0  Data Scientist
# 6            7       2021             0   Data Engineer
# 7            5       2020             0  Data Scientist
# 8          137       2022             0    Data Analyst
# 9          250       2022             0   Data Engineer
# 10         173       2022             0  Data Scientist
# 11           8       2021            50   Data Engineer
# 12           3       2023            50    Data Analyst
# 13           7       2023            50  Data Scientist
# 14           6       2022            50    Data Analyst
# 15          12       2022            50  Data Scientist
# 16           5       2021            50    Data Analyst
# 17           2       2022            50   Data Engineer
# 18          16       2021            50  Data Scientist
# 19           2       2020            50    Data Analyst
# 20           5       2020            50   Data Engineer
# 21           6       2020            50  Data Scientist
# 22          13       2021           100    Data Analyst
# 23         129       2022           100    Data Analyst
# 24           5       2020           100    Data Analyst
# 25         235       2022           100   Data Engineer
# 26           7       2020           100   Data Engineer
# 27         214       2022           100  Data Scientist
# 28          17       2021           100  Data Scientist
# 29         165       2023           100   Data Engineer
# 30          21       2021           100   Data Engineer
# 31           9       2020           100  Data Scientist
# 32         118       2023           100    Data Analyst
# 33         130       2023           100  Data Scientist

# %%
query = "SELECT AVG(salary_in_usd) AS average_salary, company_location FROM da_df WHERE job_title in ('Data Engineer', 'Data Scientist', 'Data Analyst') AND company_location in ('US', 'AU', 'GB', 'ES', 'BR') GROUP BY company_location ORDER BY average_salary DESC;"

results = execute_sql_query(query)

print(results)
# Out:
#    average_salary company_location
# 0     145691.1945               US
# 1      90884.0000               AU
# 2      82668.3874               GB
# 3      49532.3281               ES
# 4      42603.1429               BR

# %%
query = "SELECT COUNT(job_title) as total_jobs, experience_level, company_size FROM da_df WHERE job_title in ('Data Engineer', 'Data Scientist', 'Data Analyst') GROUP BY experience_level, company_size ORDER BY total_jobs DESC;"

results = execute_sql_query(query)

print(results)
# Out:
#     total_jobs experience_level company_size
# 0         1601               SE            M
# 1          435               MI            M
# 2          115               EN            M
# 3           90               SE            L
# 4           67               MI            L
# 5           64               EX            M
# 6           41               EN            L
# 7           18               EN            S
# 8           17               MI            S
# 9           12               SE            S
# 10           1               EX            L

# %%
query = "SELECT MIN(salary_in_usd) AS min_salary, company_location FROM da_df WHERE job_title in ('Data Engineer', 'Data Scientist', 'Data Analyst') AND company_location in ('US', 'AU', 'GB', 'ES', 'BR') AND employment_type in ('FT') GROUP BY company_location ORDER BY min_salary DESC;"

results = execute_sql_query(query)

print(results)
# Out:
#    min_salary company_location
# 0       42028               AU
# 1       33246               GB
# 2       31520               ES
# 3       20000               US
# 4        7799               BR

# %%
query = "SELECT MAX(salary_in_usd) AS max_salary, company_location FROM da_df WHERE job_title in ('Data Engineer', 'Data Scientist', 'Data Analyst') AND company_location in ('US', 'AU', 'GB', 'ES', 'BR') AND employment_type in ('FT') GROUP BY company_location ORDER BY min_salary DESC;"

results = execute_sql_query(query)

print(results)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/cursors.py:158, in Cursor.execute(self, query, args)
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/cursors.py:325, in Cursor._query(self, q)
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/connections.py:549, in Connection.query(self, sql, unbuffered)
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/connections.py:779, in Connection._read_query_result(self, unbuffered)
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/connections.py:1157, in MySQLResult.read(self)
#    1156 try:
# -> 1157     first_packet = self.connection._read_packet()
#    1159     if first_packet.is_ok_packet():
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/connections.py:729, in Connection._read_packet(self, packet_type)
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'min_salary' in 'order clause'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[49], line 3
#       1 query = "SELECT MAX(salary_in_usd) AS max_salary, company_location FROM da_df WHERE job_title in ('Data Engineer', 'Data Scientist', 'Data Analyst') AND company_location in ('US', 'AU', 'GB', 'ES', 'BR') AND employment_type in ('FT') GROUP BY company_location ORDER BY min_salary DESC;"
# ----> 3 results = execute_sql_query(query)
#       5 print(results)
#
# Cell In[39], line 3, in execute_sql_query(query)
#       1 def execute_sql_query(query):
#       2     engine = connection_to_sql ("project-4")
# ----> 3     results = pd.read_sql_query(query, engine)
#       4     return results
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pandas/io/sql.py:467, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     464     dtype_backend = "numpy"  # type: ignore[assignment]
#     466 with pandasSQL_builder(con) as pandas_sql:
# --> 467     return pandas_sql.read_query(
#     468         sql,
#     469         index_col=index_col,
#     470         params=params,
#     471         coerce_float=coerce_float,
#     472         parse_dates=parse_dates,
#     473         chunksize=chunksize,
#     474         dtype=dtype,
#     475         dtype_backend=dtype_backend,
#     476     )
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pandas/io/sql.py:1736, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1679 def read_query(
#    1680     self,
#    1681     sql: str,
#    (...)
#    1688     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1689 ) -> DataFrame | Iterator[DataFrame]:
#    1690     """
#    1691     Read SQL query into a DataFrame.
#    1692
#    (...)
#    1734
#    1735     """
# -> 1736     result = self.execute(sql, params)
#    1737     columns = result.keys()
#    1739     if chunksize is not None:
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pandas/io/sql.py:1560, in SQLDatabase.execute(self, sql, params)
#    1558 args = [] if params is None else [params]
#    1559 if isinstance(sql, str):
# -> 1560     return self.con.exec_driver_sql(sql, *args)
#    1561 return self.con.execute(sql, *args)
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1686, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1636 r"""Executes a SQL statement construct and returns a
#    1637 :class:`_engine.CursorResult`.
#    1638
#    (...)
#    1681
#    1682 """
#    1684 args_10style, kwargs_10style = _distill_params_20(parameters)
# -> 1686 return self._exec_driver_sql(
#    1687     statement,
#    1688     args_10style,
#    1689     kwargs_10style,
#    1690     execution_options,
#    1691     future=True,
#    1692 )
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/connections.py:549, in Connection.query(self, sql, unbuffered)
#     547     sql = sql.encode(self.encoding, "surrogateescape")
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/connections.py:779, in Connection._read_query_result(self, unbuffered)
#     777 else:
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#     781 if result.server_status is not None:
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/connections.py:1157, in MySQLResult.read(self)
#    1155 def read(self):
#    1156     try:
# -> 1157         first_packet = self.connection._read_packet()
#    1159         if first_packet.is_ok_packet():
#    1160             self._read_ok_packet(first_packet)
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/connections.py:729, in Connection._read_packet(self, packet_type)
#     727     if self._result is not None and self._result.unbuffered_active is True:
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/miniconda3/envs/ironhack/lib/python3.9/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1054, "Unknown column 'min_salary' in 'order clause'")
# [SQL: SELECT MAX(salary_in_usd) AS max_salary, company_location FROM da_df WHERE job_title in ('Data Engineer', 'Data Scientist', 'Data Analyst') AND company_location in ('US', 'AU', 'GB', 'ES', 'BR') AND employment_type in ('FT') GROUP BY company_location ORDER BY min_salary DESC;]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
